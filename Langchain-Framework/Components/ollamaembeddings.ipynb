# %% [markdown]
# Ollama
#
# ollama supports embedding models, making it possible to build retireval augumented generation(RAG) applications that combine text prompts with existing documents or other data.
#
# Ollama – Models Summary:
# https://github.com/ollama/ollama
#
# Ollama embedding models?
# https://ollama.com/blog/embedding-models

# %%
from langchain_community.embeddings import OllamaEmbeddings
ollama_embeddings = (
    OllamaEmbeddings(model="gemma:2b", base_url="http://localhost:11434")
)
ollama_embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = ollama_embeddings.embed_documents(
    [
"LangChain is a framework for developing applications powered by language models.",
"LangChain provides a standard interface for connecting to various language models and tools."
    ]
)
r1

# %%
len(r1[0])
# Out:
# 2048

# %%
from langchain_community.embeddings import OllamaEmbeddings
OllamaEmbeddings(model="mxbai-embed-large")
ollama_embeddings.embed_query("What is LangChain?")
# Out:
# [0.2386510968208313,
#  -1.1124762296676636,
#  -0.49963632225990295,
#  1.804184079170227,
#  1.4643741846084595,
#  0.8389377593994141,
#  -0.5263774991035461,
#  -0.3529711365699768,
#  0.9565439820289612,
#  -0.644242525100708,
#  0.47356531023979187,
#  1.3782049417495728,
#  -0.4564787447452545,
#  -0.18298742175102234,
#  0.20435266196727753,
#  -0.8220166563987732,
#  6.269579887390137,
#  -0.5374021530151367,
#  0.0374189168214798,
#  0.23625370860099792,
#  1.7409956455230713,
#  0.4099482297897339,
#  0.42482125759124756,
#  1.2737945318222046,
#  -2.063253879547119,
#  -1.0407038927078247,
#  0.7827678322792053,
#  0.5840613842010498,
#  -0.39622506499290466,
#  -2.994828701019287,
#  0.2267618477344513,
#  1.073606014251709,
#  1.5696312189102173,
#  0.9495574831962585,
#  -0.9547666311264038,
#  1.7814149856567383,
#  0.8869203329086304,
#  1.789054036140442,
#  0.5843456387519836,
#  -0.7716982960700989,
#  0.37851211428642273,
#  0.6284589171409607,
# ...
